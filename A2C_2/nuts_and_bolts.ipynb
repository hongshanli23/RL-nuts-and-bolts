# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

logfile = '/home/ubuntu/tmp/logs/a2c/cartpole/progress.csv'

prog =pd.read_csv(logfile)#.dropna()

prog
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-5b51883c5ba7> in <module>
#       6 logfile = '/home/ubuntu/tmp/logs/a2c/cartpole/progress.csv'
#       7
# ----> 8 prog =pd.read_csv(logfile)#.dropna()
#       9
#      10 prog
#
# ...

# %%
! ls /home/ubuntu/tmp/logs/a2c/cartpole/
# Out:
# ckpt.pth  log.txt  optim.pth

# %%
for c in prog.columns:
    print(c)
    plt.plot(prog[c])
    plt.show()
    print()
# Out:
# FPS
# MAEpLen
# MAEpRet
# MeanStepRew
# PolicyNetAvgW
# Q
# VQDiff
# ValueNetAvgW
# explained_variance
# iteration
# loss
# vpreds

# %%
{'Q': array([[1.4954083 , 1.3362362 ],
       [1.006762  , 0.8995987 ],
       [0.5131551 , 0.47177407]], dtype=float32),
 'actions': array([[[-0.08285457],
        [ 0.14278477]],

       [[ 1.7958046 ],
        [ 0.2489313 ]],

       [[-0.23458841],
        [ 0.2916725 ]]], dtype=float32),
 'dones': array([[False, False],
       [False, False],
       [False, False]]),
 'ep_lens': [[], []],
 'ep_rets': [[], []],
 'log_prob': array([[[-0.94499063],
        [-0.92351246]],

       [[-2.497613  ],
        [-0.9316685 ]],

       [[-0.95238566],
        [-0.93057346]]], dtype=float32),
 'obs': array([[[ 0.9913728 ,  0.131072  , -0.18146266],
        [ 0.60726476,  0.7944995 ,  0.51753396]],

       [[ 0.99198794,  0.12633242, -0.09558684],
        [ 0.5612307 ,  0.8276594 ,  1.1348263 ]],

       [[ 0.99020237,  0.1396397 ,  0.26853317],
        [ 0.48488048,  0.87458044,  1.7929106 ]]], dtype=float32),
 'rews': array([[0.49871382, 0.44563347],
       [0.4987385 , 0.43254235],
       [0.49831918, 0.40907207]], dtype=float32),
 'vpreds': array([[0.00328532, 0.02011862],
       [0.00517557, 0.03376087],
       [0.01335584, 0.04819034]], dtype=float32)}
